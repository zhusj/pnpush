# %%
# %matplotlib inline

import os
import os.path as osp
import sys
# import Image
# import sys
import argparse
import os, tempfile, glob, shutil
import random
from datetime import datetime
random.seed(datetime.now())

# import gaussian_process
import GPy
import GPyOpt
import subprocess as sub
import numpy as np
import scipy.spatial
import math
import matplotlib.pyplot as plt
from numpy import linalg as LA

from scipy import optimize
import time

global g_blender_executable_path,  blank_file, render_code, model_file, table_file, temp_dirname, epsilon, \
       filename, time, location_gt, rotation_gt


epsilon = 1e-6


if os.environ.get('BLENDER_PATH') == None:
    print("Please set BLENDER_PATH in bashrc!")
    sys.exit()

g_blender_executable_path = os.environ['BLENDER_PATH']

obj_model_folder = 'obj_models/'
table_model_folder = 'table_models/'

g_blank_blend_file_path = 'blank.blend'
syn_images_folder = 'rendered_images'
if not os.path.exists(syn_images_folder):
    os.mkdir(syn_images_folder)

all_models = []
for file in os.listdir(obj_model_folder):
    if file.endswith(".obj"):
        all_models.append(file)

print(all_models)

# random select model in all_models
# To Do

# model_name and table_name are hard coded
model_name = 'expo_dry_erase_board_eraser'
robot_name = 'reflex'

########################### Input and GT ####################
fps = 24

path = '/home/zhusj/Dropbox/16fall/learningPhysics/data/data/trial4/'

filelist = ['exp1', 'exp2', 'exp3']
timelist = [8,4,1]

location_gt = []
rotation_gt = []

for file in filelist:
    count = 0
    filename = path+file+'.txt'
    with open(filename) as f:

        obj_start_config = []
        hand_start_config = []
        obj_end_config = []
        hand_end_config = []
        for line in f: # read rest of lines
            if count == 7: 
                obj_end_config.append([float(x) for x in line.split()])
            count += 1

    print obj_end_config
    myorder=[0,1,2,6,3,4,5]
    obj_end_config = [ obj_end_config[0][i] for i in myorder]
    print obj_end_config


    obj_end_config = np.array(obj_end_config)
    print obj_end_config.shape

    location_gt.append(obj_end_config[:3])
    rotation_gt.append(obj_end_config[3:])

print location_gt, rotation_gt
##############################################

table_name = 'table'
arm_name ='arm'
image_name = 'demo_img.png'
output_img = osp.join(syn_images_folder, image_name)
output_blend = osp.join(syn_images_folder, image_name+'.blend')

# call blender to render images
blank_file = osp.join(g_blank_blend_file_path)
render_code = osp.join('render_physics_reflex_expo.py')
model_file = osp.join(obj_model_folder, model_name+ '.obj')
robot_file = osp.join(obj_model_folder, robot_name+ '.obj')
table_file = osp.join(table_model_folder, table_name+ '.obj')
# print render_code
# print model_file
temp_dirname = '/home/zhusj/repos/blender_scene_generator/test'  #tempfile.mkdtemp()
# Out:
# ['crayola_24_ct.obj', 'pliers.obj', 'scotch_duct_tape.obj', 'folgers_classic_roast_coffee_00000.obj', 'expo_dry_erase_board_eraser.obj', 'reflex.obj', 'reflex_nc.obj', 'kleenex_tissue_box.obj', 'dasani_water_bottle.obj', 'robotiq.obj', 'expo_dry_erase_board_eraser_00000.obj', 'folgers_classic_roast_coffee.obj']
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-323fd85acbef> in <module>()
#      73     count = 0
#      74     filename = path+file+'.txt'
# ---> 75     with open(filename) as f:
#      76
#      77         obj_start_config = []
#
# IOError: [Errno 2] No such file or directory: '/home/zhusj/Dropbox/16fall/learningPhysics/data/data/trial4/exp1.txt'

# %%
def run_physics_engine(filename, mass, friction, force, time):

    location =[]
    rotation = []    

    render_cmd = '%s %s -b --python %s -- %s %s %s %s %s %s %s %s %s' % \
    (g_blender_executable_path, blank_file, render_code, robot_file, model_file, time, \
    filename, force_gt, mass, friction, table_file, temp_dirname)

    p = os.popen(render_cmd,"r")
    while 1:
        line = p.readline()
        if not line: break
        if "location" in line: 
            print "output:", line
            vals = line.split(',')
            count = 0
            for val in vals:
                count += 1
                if count == 1:
                    x= float(val[-6:])
                if count == 2:
                    y= float(val[-7:])

        if "rotation" in line: 
            print "output:", line
            vals = line.split(',')
            count = 0
            for val in vals:
                count += 1
                if count == 1:
                    qw= float(val[-6:])
                if count == 2:
                    qx= float(val[-6:])
                if count == 3:
                    qy= float(val[-6:])
                if count == 4:
                    newstr = val[-10:-3].replace("=", "")
                    qz= float(newstr)
                    
    location.append([x, y])
    location = np.asarray(location)
    rotation.append([qw,qx,qy,qz])
    rotation = np.asarray(rotation)
    return location, rotation

# %%
def myf(X):

    mass = X[0][0]
    friction = X[0][1]
    
    y_new = 0
    count = 0
    for file in filelist:        
        filename = path+file+'.txt'
        time = timelist[count]*fps
#         print 'input: ', filename, mass, friction, force_gt, time
        
        location, rotation = run_physics_engine(filename, mass, friction, force_gt, time)  
        dist = np.sqrt(np.sum(((location-location_gt[count][0:2])**2)))
        q_dist = 1 - np.sum(np.multiply(rotation, rotation_gt[count]))**2
        

        print dist, q_dist
        y_new += dist + q_dist
        count += 1

    print "X, y_new",X,y_new

    return y_new

# %%
from GPyOpt.acquisitions.EI import AcquisitionEI
from GPyOpt.acquisitions.MPI import AcquisitionMPI

objective = GPyOpt.core.task.SingleObjective(myf)
space = GPyOpt.Design_space(space =[{'name': 'mass', 'type': 'continuous', 'domain': (0.0,0.5)},
                                    {'name': 'friction', 'type': 'continuous', 'domain': (0.01,0.7)}])

model = GPyOpt.models.GPModel(optimize_restarts=5,verbose=False, normalize_Y = False)

aquisition_optimizer = GPyOpt.optimization.AcquisitionOptimizer(space)
initial_design = GPyOpt.util.stats.initial_design('random', space, 10)

acquisition = AcquisitionMPI(model, space, optimizer=aquisition_optimizer) 

evaluator = GPyOpt.core.evaluators.Sequential(acquisition)

# %%
BO_result = []
BO_time =[]
from GPyOpt.acquisitions.EI import AcquisitionEI
from GPyOpt.acquisitions.MPI import AcquisitionMPI
force_gt = float(48)

for count in xrange(0,5):
    random.seed(datetime.now())
    ############### BO ######################
#     import pdb; pdb.set_trace()
    objective = GPyOpt.core.task.SingleObjective(myf)
    space = GPyOpt.Design_space(space =[{'name': 'mass', 'type': 'continuous', 'domain': (0.0,0.5)},
                                        {'name': 'friction', 'type': 'continuous', 'domain': (0.01,0.7)}])

    model = GPyOpt.models.GPModel(optimize_restarts=5,verbose=False, normalize_Y = False)

    aquisition_optimizer = GPyOpt.optimization.AcquisitionOptimizer(space)
    initial_design = GPyOpt.util.stats.initial_design('random', space, 10)

    acquisition = AcquisitionMPI(model, space, optimizer=aquisition_optimizer) 

    evaluator = GPyOpt.core.evaluators.Sequential(acquisition)
    myBopt = GPyOpt.methods.ModularBayesianOptimization(model, space, objective, acquisition, evaluator, \
                                                        initial_design)

    max_time = 300
    max_iter = 30
#     myBopt.run_optimization(max_time=max_time)
    myBopt.run_optimization(max_iter=max_iter,max_time=max_time)

    print "optima!!!!!!!!!!!!!!!!: ", myBopt.x_opt, myBopt.fx_opt, myBopt.cum_time
    
    BO_result.append(myBopt)
    BO_time.append(myBopt.cum_time)
    
# exp1: 0.543561 -0.123172 0.54746 0.62389 -0.00114687 0.00659373 -0.781483
# exp2: 0.532153 -0.0257914 0.548445 -0.430238 -0.00623893 -0.00737948 0.902664
# exp3: 0.48143 -0.0221645 0.54965 -0.234441 -0.00235522 -0.00839558 0.972091 

# exp8: 0.423403 0.229149 0.558357 -0.232128 -0.00738495 -0.0275467 0.972267
# Out:
# output: location:  <Vector (0.5603, -0.1318, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.6177, x=-0.0012, y=-0.0037, z=-0.7864)>
#
# 0.0188317950552 8.37887307886e-05
# output: location:  <Vector (0.5616, -0.0508, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3616, x=0.0016, y=0.0006, z=-0.9323)>
#
# 0.0386336107937 0.00570759655834
# output: location:  <Vector (0.4627, -0.0151, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.2303, x=-0.0116, y=-0.0030, z=-0.9730)>
#
# 0.0200179934122 0.00022236245336
# X, y_new [[ 0.14426116  0.67207892]] 0.0834971470035
# output: location:  <Vector (0.5599, -0.1412, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4976, x=0.0040, y=-0.0002, z=-0.8674)>
#
# 0.0243304686556 0.0232576753979
# output: location:  <Vector (0.5594, -0.0473, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3348, x=0.0009, y=-0.0002, z=-0.9423)>
#
# 0.0347133819004 0.010709053423
# output: location:  <Vector (0.4669, -0.0257, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.1960, x=0.0093, y=-0.0007, z=-0.9806)>
#
# 0.0149539513257 0.00157807482424
# X, y_new [[ 0.39661137  0.29505883]] 0.109542605527
# output: location:  <Vector (0.5623, -0.1379, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.5334, x=-0.0024, y=-0.0051, z=-0.8458)>
#
# 0.0238340954307 0.0123772163923
# output: location:  <Vector (0.5612, -0.0488, 0.7742)>
#
# output: rotation:  <Quaternion (w=0.3522, x=-0.0145, y=-0.0023, z=-0.9358)>
#
# 0.0370556862433 0.0072862150162
# output: location:  <Vector (0.4892, -0.0456, 0.7735)>
#
# output: rotation:  <Quaternion (w=0.0221, x=-0.0022, y=-0.0008, z=-0.9998)>
#
# 0.0246899890695 0.0452958630602
# X, y_new [[ 0.13515525  0.27132507]] 0.150539065212
# output: location:  <Vector (0.5532, -0.1377, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4962, x=0.0055, y=-0.0003, z=-0.8682)>
#
# 0.0174348244901 0.0237504215718
# output: location:  <Vector (0.5597, -0.0503, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3319, x=-0.0017, y=-0.0016, z=-0.9433)>
#
# 0.0368715158755 0.0113648119671
# output: location:  <Vector (0.4682, -0.0051, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3259, x=-0.0000, y=-0.0001, z=-0.9454)>
#
# 0.021592361155 0.00913903781858
# X, y_new [[ 0.22228129  0.51816258]] 0.120152972878
# output: location:  <Vector (0.5632, -0.1431, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4829, x=-0.0022, y=-0.0006, z=-0.8757)>
#
# 0.0279788403083 0.0285481352663
# output: location:  <Vector (0.5581, -0.0455, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3590, x=0.0030, y=0.0017, z=-0.9333)>
#
# 0.0325833657402 0.00610462463136
# output: location:  <Vector (0.4692, -0.0104, 0.7736)>
#
# output: rotation:  <Quaternion (w=0.1692, x=0.0128, y=-0.0047, z=-0.9855)>
#
# 0.0169698662414 0.00452945188368
# X, y_new [[ 0.20122214  0.31835489]] 0.116714284071
# output: location:  <Vector (0.5526, -0.1371, 0.7760)>
#
# output: rotation:  <Quaternion (w=0.5257, x=-0.0201, y=-0.0151, z=-0.8503)>
#
# 0.0166039966574 0.0148435423967
# output: location:  <Vector (0.5614, -0.0519, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3263, x=0.0003, y=-0.0002, z=-0.9453)>
#
# 0.0392051782672 0.0126034635843
# output: location:  <Vector (0.4733, -0.0024, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3698, x=-0.0033, y=-0.0006, z=-0.9291)>
#
# 0.0213712975799 0.0201398831616
# X, y_new [[ 0.14559404  0.54185644]] 0.124767361647
# output: location:  <Vector (0.5644, -0.1374, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5453, x=-0.0000, y=-0.0001, z=-0.8383)>
#
# 0.0252329131295 0.0093279945328
# output: location:  <Vector (0.5499, -0.0315, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.3894, x=-0.0079, y=-0.0053, z=-0.9210)>
#
# 0.0186425353147 0.00204571271136
# output: location:  <Vector (0.4732, -0.0287, 0.7736)>
#
# output: rotation:  <Quaternion (w=0.1065, x=-0.0049, y=-0.0086, z=-0.9943)>
#
# 0.0105093130246 0.0167258893429
# X, y_new [[ 0.00174775  0.21975034]] 0.0824843580559
# output: location:  <Vector (0.5612, -0.1430, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4820, x=-0.0023, y=-0.0045, z=-0.8761)>
#
# 0.0265383478197 0.0289882781238
# output: location:  <Vector (0.5641, -0.0531, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3269, x=0.0013, y=0.0012, z=-0.9451)>
#
# 0.0420282100851 0.0124221518815
# output: location:  <Vector (0.4706, -0.0172, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.1554, x=0.0022, y=0.0067, z=-0.9878)>
#
# 0.0119136543617 0.00653916858261
# X, y_new [[ 0.22632381  0.42247561]] 0.128429810854
# output: location:  <Vector (0.5574, -0.1315, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.5784, x=0.0006, y=-0.0004, z=-0.8158)>
#
# 0.016151579025 0.00320990644269
# output: location:  <Vector (0.5383, -0.0160, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3207, x=0.0000, y=-0.0000, z=-0.9472)>
#
# 0.0115610173843 0.0139893941699
# output: location:  <Vector (0.4837, -0.0468, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.0369, x=-0.0000, y=-0.0000, z=-0.9993)>
#
# 0.024739861767 0.0394796341969
# X, y_new [[ 0.0627639   0.15788538]] 0.109131392986
# output: location:  <Vector (0.5623, -0.1418, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5062, x=0.0012, y=0.0001, z=-0.8624)>
#
# 0.0264225756693 0.0203685301408
# output: location:  <Vector (0.5675, -0.0530, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3927, x=-0.0013, y=0.0005, z=-0.9197)>
#
# 0.0446062587869 0.00170658377301
# output: location:  <Vector (0.4677, -0.0191, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.1813, x=-0.0001, y=-0.0000, z=-0.9834)>
#
# 0.0140678377958 0.00308026788318
# X, y_new [[ 0.17366695  0.41111718]] 0.110252054049
# output: location:  <Vector (0.5578, -0.1377, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5118, x=-0.0002, y=-0.0001, z=-0.8591)>
#
# 0.0203423672418 0.0185543713945
# output: location:  <Vector (0.5543, -0.0363, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4061, x=0.0024, y=-0.0001, z=-0.9138)>
#
# 0.0245136754274 0.000820378915557
# output: location:  <Vector (0.4606, -0.0309, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.1706, x=-0.0083, y=0.0001, z=-0.9853)>
#
# 0.022587559856 0.00436066618629
# X, y_new [[ 0.00127086  0.21761179]] 0.0911790190215
# output: location:  <Vector (0.5590, -0.1354, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.5417, x=-0.0053, y=0.0030, z=-0.8405)>
#
# 0.0196948395525 0.0103503236363
# output: location:  <Vector (0.5593, -0.0406, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4178, x=-0.0010, y=-0.0027, z=-0.9085)>
#
# 0.0309233607967 0.000300289601153
# output: location:  <Vector (0.4622, -0.0333, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.1249, x=0.0003, y=-0.0016, z=-0.9922)>
#
# 0.0222214369529 0.012352594723
# X, y_new [[ 0.00226777  0.22239204]] 0.0958428452625
# output: location:  <Vector (0.5582, -0.1316, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.6073, x=0.0007, y=0.0097, z=-0.7944)>
#
# 0.0168917584934 0.000476646044597
# output: location:  <Vector (0.5655, -0.0524, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3701, x=0.0013, y=0.0018, z=-0.9290)>
#
# 0.0426619268547 0.00434061257416
# output: location:  <Vector (0.4726, -0.0029, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3791, x=-0.0059, y=-0.0010, z=-0.9254)>
#
# 0.021191740378 0.0229233308288
# X, y_new [[ 0.14397881  0.67822479]] 0.108486015174
# output: location:  <Vector (0.5611, -0.1315, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.6167, x=0.0008, y=0.0015, z=-0.7872)>
#
# 0.0194157694929 0.000109289615782
# output: location:  <Vector (0.5609, -0.0531, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3222, x=0.0017, y=0.0007, z=-0.9467)>
#
# 0.0396503422805 0.0135727017884
# output: location:  <Vector (0.4758, 0.0017, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3446, x=0.0057, y=0.0058, z=-0.9387)>
#
# 0.0245196097084 0.0132511893739
# X, y_new [[ 0.14435802  0.66997427]] 0.11051890226
# output: location:  <Vector (0.5540, -0.1386, 0.7761)>
#
# output: rotation:  <Quaternion (w=0.5183, x=-0.0226, y=-0.0116, z=-0.8548)>
#
# 0.0186278260943 0.0170776126741
# output: location:  <Vector (0.5607, -0.0526, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3161, x=-0.0036, y=-0.0027, z=-0.9487)>
#
# 0.0391616169605 0.0151463021986
# output: location:  <Vector (0.4691, -0.0037, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3312, x=0.0002, y=0.0003, z=-0.9435)>
#
# 0.0222028525251 0.0103377290076
# X, y_new [[ 0.14442714  0.67380104]] 0.12255393946
# output: location:  <Vector (0.5573, -0.1354, 0.7764)>
#
# output: rotation:  <Quaternion (w=0.5790, x=-0.0225, y=-0.0161, z=-0.8149)>
#
# 0.0183925013253 0.00371022979359
# output: location:  <Vector (0.5620, -0.0494, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3803, x=0.0022, y=-0.0001, z=-0.9249)>
#
# 0.0380553465752 0.00298195647524
# output: location:  <Vector (0.4813, 0.0048, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3382, x=-0.0027, y=0.0013, z=-0.9411)>
#
# 0.0269648133732 0.0116855418031
# X, y_new [[ 0.12896082  0.68754196]] 0.101790389346
# output: location:  <Vector (0.5541, -0.1370, 0.7768)>
#
# output: rotation:  <Quaternion (w=0.5427, x=-0.0312, y=-0.0214, z=-0.8391)>
#
# 0.0173863194783 0.0111033828593
# output: location:  <Vector (0.5606, -0.0493, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3625, x=-0.0019, y=0.0002, z=-0.9320)>
#
# 0.0369037407719 0.0054775727092
# output: location:  <Vector (0.4745, -0.0014, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3663, x=0.0001, y=-0.0012, z=-0.9305)>
#
# 0.0218903942461 0.0190747127855
# X, y_new [[ 0.14045154  0.67016893]] 0.11183612285
# optima!!!!!!!!!!!!!!!!:  [ 0.00174775  0.21975034] [ 0.08248436] 331.066638947
# output: location:  <Vector (0.5447, -0.0755, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.4442, x=-0.0021, y=-0.0001, z=-0.8959)>
#
# 0.0476856047985 0.0449613118846
# output: location:  <Vector (0.5709, 0.0115, 0.7740)>
#
# output: rotation:  <Quaternion (w=0.4975, x=-0.0229, y=-0.0069, z=-0.8671)>
#
# 0.0537771189537 0.00611632032764
# output: location:  <Vector (0.4737, -0.0881, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.1683, x=-0.0109, y=0.0047, z=0.9857)>
#
# 0.0663870699779 0.156048100246
# X, y_new [[ 0.08443106  0.05196683]] 0.374975526188
# output: location:  <Vector (0.5576, -0.1387, 0.7768)>
#
# output: rotation:  <Quaternion (w=0.5433, x=-0.0292, y=-0.0187, z=-0.8388)>
#
# 0.0209335210846 0.0108559927421
# output: location:  <Vector (0.5608, -0.0527, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3265, x=0.0008, y=-0.0007, z=-0.9452)>
#
# 0.0393029688823 0.0125983155192
# output: location:  <Vector (0.4736, -0.0005, 0.7736)>
#
# output: rotation:  <Quaternion (w=0.3939, x=-0.0044, y=0.0094, z=-0.9191)>
#
# 0.0230360469753 0.0280318918272
# X, y_new [[ 0.03852122  0.533582  ]] 0.134758737031
# output: location:  <Vector (0.5676, -0.1452, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4959, x=-0.0011, y=-0.0023, z=-0.8684)>
#
# 0.0326053109938 0.0237753929053
# output: location:  <Vector (0.5556, -0.0409, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3803, x=0.0002, y=0.0000, z=-0.9249)>
#
# 0.0278932178667 0.00300834847819
# output: location:  <Vector (0.4747, -0.0322, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.1441, x=-0.0003, y=0.0021, z=-0.9896)>
#
# 0.0120832181247 0.00841713505458
# X, y_new [[ 0.08171731  0.2919494 ]] 0.107782623423
# output: location:  <Vector (0.5549, -0.1377, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.4991, x=-0.0033, y=-0.0022, z=-0.8666)>
#
# 0.018429207932 0.0226158870339
# output: location:  <Vector (0.5658, -0.0499, 0.7742)>
#
# output: rotation:  <Quaternion (w=0.3867, x=-0.0214, y=-0.0048, z=-0.9220)>
#
# 0.041392574249 0.00240220120997
# output: location:  <Vector (0.4637, -0.0115, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.2312, x=-0.0000, y=-0.0000, z=-0.9729)>
#
# 0.020690202035 9.98113093015e-05
# X, y_new [[ 0.20954737  0.30804051]] 0.105629883769
# output: location:  <Vector (0.5569, -0.1193, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4174, x=0.0007, y=0.0019, z=-0.9087)>
#
# 0.0138896114057 0.0580190837828
# output: location:  <Vector (0.5593, -0.0346, 0.7745)>
#
# output: rotation:  <Quaternion (w=0.4160, x=-0.0014, y=0.0029, z=-0.9094)>
#
# 0.0285403406245 0.000216419101426
# output: location:  <Vector (0.4629, -0.0511, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.0591, x=-0.0006, y=-0.0005, z=0.9983)>
#
# 0.0343602104221 0.0849597327589
# X, y_new [[ 0.29704514  0.12420293]] 0.219985398095
# output: location:  <Vector (0.5554, -0.1355, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.4930, x=-0.0093, y=-0.0055, z=-0.8699)>
#
# 0.017092147466 0.0250107659832
# output: location:  <Vector (0.5512, -0.0354, 0.7745)>
#
# output: rotation:  <Quaternion (w=0.3874, x=0.0112, y=0.0076, z=-0.9218)>
#
# 0.0213333870485 0.00224706332834
# output: location:  <Vector (0.4706, -0.0407, 0.7737)>
#
# output: rotation:  <Quaternion (w=0.0544, x=-0.0027, y=0.0061, z=-0.9985)>
#
# 0.0214675024223 0.032837847662
# X, y_new [[ 0.29135301  0.18681131]] 0.11998871391
# output: location:  <Vector (0.5576, -0.1377, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.5141, x=0.0010, y=-0.0017, z=-0.8578)>
#
# 0.0202028786315 0.0177048751074
# output: location:  <Vector (0.5505, -0.0359, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3833, x=-0.0011, y=-0.0004, z=-0.9236)>
#
# 0.0209474629242 0.00275707617849
# output: location:  <Vector (0.4732, -0.0272, 0.7714)>
#
# output: rotation:  <Quaternion (w=0.1599, x=-0.0298, y=-0.0112, z=-0.9866)>
#
# 0.00964827239717 0.00655659229274
# X, y_new [[ 0.29325431  0.21910851]] 0.0778171575315
# output: location:  <Vector (0.5568, -0.1400, 0.7758)>
#
# output: rotation:  <Quaternion (w=0.5127, x=-0.0131, y=-0.0078, z=-0.8584)>
#
# 0.0214115087044 0.0184544291187
# output: location:  <Vector (0.5607, -0.0526, 0.7736)>
#
# output: rotation:  <Quaternion (w=0.3225, x=0.0257, y=0.0061, z=-0.9462)>
#
# 0.0391616169605 0.0138362314225
# output: location:  <Vector (0.4736, 0.0000, 0.7740)>
#
# output: rotation:  <Quaternion (w=0.4086, x=-0.0067, y=0.0066, z=-0.9127)>
#
# 0.0235068917607 0.0335316156009
# X, y_new [[ 0.19320468  0.57755905]] 0.149902293568
# output: location:  <Vector (0.5597, -0.1403, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4900, x=-0.0011, y=-0.0015, z=-0.8717)>
#
# 0.0235337142202 0.02596234526
# output: location:  <Vector (0.5601, -0.0461, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.3681, x=0.0044, y=0.0042, z=-0.9298)>
#
# 0.0345466936618 0.00454274889041
# output: location:  <Vector (0.4672, -0.0189, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.1983, x=0.0015, y=-0.0025, z=-0.9801)>
#
# 0.0145996527442 0.00147833087023
# X, y_new [[ 0.44513958  0.45403667]] 0.104663485647
# output: location:  <Vector (0.5570, -0.1284, 0.7745)>
#
# output: rotation:  <Quaternion (w=0.5357, x=-0.0034, y=0.0012, z=-0.8444)>
#
# 0.0144200799235 0.011752999676
# output: location:  <Vector (0.5490, -0.0254, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4136, x=-0.0009, y=-0.0003, z=-0.9105)>
#
# 0.016851546011 0.000340295682785
# output: location:  <Vector (0.4684, -0.0584, 0.7713)>
#
# output: rotation:  <Quaternion (w=0.0584, x=-0.0229, y=-0.0031, z=-0.9980)>
#
# 0.0385070429954 0.0319051070894
# X, y_new [[ 0.10934135  0.12217504]] 0.113777071378
# output: location:  <Vector (0.5550, -0.1362, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.4954, x=-0.0069, y=-0.0034, z=-0.8686)>
#
# 0.0173372288732 0.0240817546697
# output: location:  <Vector (0.5489, -0.0376, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.2822, x=0.0020, y=0.0037, z=-0.9593)>
#
# 0.0204915846864 0.0250836567892
# output: location:  <Vector (0.4620, -0.0269, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.1832, x=-0.0033, y=-0.0038, z=-0.9831)>
#
# 0.019998746467 0.00269432524385
# X, y_new [[ 0.29288999  0.21675682]] 0.109687296729
# output: location:  <Vector (0.5579, -0.1356, 0.7741)>
#
# output: rotation:  <Quaternion (w=0.5327, x=0.0094, y=0.0071, z=-0.8462)>
#
# 0.0189753025009 0.0126136659908
# output: location:  <Vector (0.5575, -0.0423, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3692, x=0.0006, y=0.0013, z=-0.9293)>
#
# 0.0302490377196 0.00458900019063
# output: location:  <Vector (0.4716, -0.0312, 0.7741)>
#
# output: rotation:  <Quaternion (w=0.0814, x=-0.0172, y=-0.0028, z=-0.9965)>
#
# 0.0133517474605 0.0241796492637
# X, y_new [[ 0.29334641  0.21969204]] 0.103958403126
# output: location:  <Vector (0.5607, -0.1415, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.4963, x=0.0059, y=-0.0029, z=-0.8681)>
#
# 0.0250930449527 0.0237485923876
# output: location:  <Vector (0.5569, -0.0323, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3648, x=-0.0036, y=0.0009, z=-0.9311)>
#
# 0.0255885889208 0.00509275044971
# output: location:  <Vector (0.4697, -0.0443, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.0473, x=-0.0038, y=0.0005, z=-0.9989)>
#
# 0.0250514123404 0.0354326316408
# X, y_new [[ 0.29101292  0.17333229]] 0.140007020692
# output: location:  <Vector (0.5605, -0.1394, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5149, x=0.0008, y=0.0011, z=-0.8572)>
#
# 0.0234579987424 0.017652354925
# output: location:  <Vector (0.5613, -0.0508, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3255, x=0.0035, y=-0.0009, z=-0.9455)>
#
# 0.0384054381951 0.0128787477095
# output: location:  <Vector (0.4626, -0.0221, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.2436, x=0.0027, y=0.0044, z=-0.9699)>
#
# 0.0188301104683 3.16234579854e-05
# X, y_new [[ 0.45632211  0.43642734]] 0.111256273498
# output: location:  <Vector (0.5603, -0.1413, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.5005, x=0.0050, y=0.0029, z=-0.8657)>
#
# 0.0246742478102 0.0222742325747
# output: location:  <Vector (0.5597, -0.0512, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3291, x=0.0005, y=0.0002, z=-0.9443)>
#
# 0.0374757810187 0.0120007053734
# output: location:  <Vector (0.4584, -0.0154, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.2843, x=0.0094, y=-0.0030, z=-0.9587)>
#
# 0.024002903163 0.00271306969669
# X, y_new [[ 0.43018473  0.43860013]] 0.123140939637
# output: location:  <Vector (0.5537, -0.1368, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4987, x=-0.0031, y=-0.0013, z=-0.8668)>
#
# 0.0169859266748 0.022811555039
# output: location:  <Vector (0.5586, -0.0507, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3238, x=0.0010, y=0.0009, z=-0.9461)>
#
# 0.0363301825341 0.0132868586562
# output: location:  <Vector (0.4749, -0.0308, 0.7723)>
#
# output: rotation:  <Quaternion (w=0.1357, x=0.0337, y=0.0104, z=-0.9901)>
#
# 0.0108264842054 0.0110739156704
# X, y_new [[ 0.46603727  0.46179233]] 0.11131492278
# output: location:  <Vector (0.5591, -0.1418, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.4800, x=0.0033, y=0.0061, z=-0.8772)>
#
# 0.0242582543684 0.0297345659552
# output: location:  <Vector (0.5596, -0.0445, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3591, x=-0.0014, y=-0.0005, z=-0.9333)>
#
# 0.0332167054802 0.00605639964769
# output: location:  <Vector (0.4658, -0.0174, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.2006, x=-0.0040, y=-0.0001, z=-0.9797)>
#
# 0.0163400538631 0.00120628052625
# X, y_new [[ 0.1875078   0.31474421]] 0.110812259841
# optima!!!!!!!!!!!!!!!!:  [ 0.29325431  0.21910851] [ 0.07781716] 330.227690935
# output: location:  <Vector (0.5557, -0.1382, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5172, x=0.0012, y=0.0000, z=-0.8558)>
#
# 0.0193182842147 0.0169918332573
# output: location:  <Vector (0.5646, -0.0566, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3320, x=0.0007, y=0.0006, z=-0.9433)>
#
# 0.0447434648073 0.0113063354641
# output: location:  <Vector (0.4735, -0.0018, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.3391, x=-0.0069, y=-0.0011, z=-0.9407)>
#
# 0.021854010164 0.0120227784093
# X, y_new [[ 0.12864731  0.47378994]] 0.126236706317
# output: location:  <Vector (0.5631, -0.1313, 0.7742)>
#
# output: rotation:  <Quaternion (w=0.5236, x=-0.0088, y=-0.0030, z=-0.8519)>
#
# 0.0211621573806 0.0150948812413
# output: location:  <Vector (0.5538, -0.0342, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3858, x=0.0005, y=0.0003, z=-0.9226)>
#
# 0.023222772508 0.00242061316438
# output: location:  <Vector (0.4815, -0.0403, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.1218, x=0.0009, y=-0.0005, z=-0.9926)>
#
# 0.0181356350936 0.0130396963756
# X, y_new [[ 0.48229013  0.18552873]] 0.0930757557635
# output: location:  <Vector (0.5565, -0.1376, 0.7768)>
#
# output: rotation:  <Quaternion (w=0.5517, x=-0.0299, y=-0.0200, z=-0.8333)>
#
# 0.0193800130289 0.00896485709083
# output: location:  <Vector (0.5596, -0.0491, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.3197, x=-0.0030, y=-0.0072, z=-0.9475)>
#
# 0.0360087300937 0.0141633363627
# output: location:  <Vector (0.4715, -0.0214, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.1470, x=-0.0047, y=-0.0008, z=-0.9891)>
#
# 0.00995938553576 0.00803216378816
# X, y_new [[ 0.27961164  0.58682556]] 0.0965084859
# output: location:  <Vector (0.5563, -0.1348, 0.7763)>
#
# output: rotation:  <Quaternion (w=0.5820, x=-0.0207, y=-0.0145, z=-0.8128)>
#
# 0.0172479710401 0.00326686497922
# output: location:  <Vector (0.5709, -0.0534, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3983, x=0.0012, y=-0.0003, z=-0.9173)>
#
# 0.0475769356197 0.00122525813552
# output: location:  <Vector (0.4692, -0.0057, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.3725, x=0.0017, y=0.0044, z=-0.9280)>
#
# 0.0205098186304 0.0209478032509
# X, y_new [[ 0.03298865  0.63814376]] 0.110774651656
# output: location:  <Vector (0.5637, -0.1383, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5451, x=-0.0006, y=-0.0008, z=-0.8384)>
#
# 0.0251880071661 0.00941299787207
# output: location:  <Vector (0.5545, -0.0435, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3264, x=-0.0004, y=0.0010, z=-0.9452)>
#
# 0.0285128553982 0.0126843773939
# output: location:  <Vector (0.4745, -0.0313, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.1410, x=-0.0034, y=-0.0005, z=-0.9900)>
#
# 0.0114665714252 0.00910223942771
# X, y_new [[ 0.44281313  0.281591  ]] 0.0963670486832
# output: location:  <Vector (0.5609, -0.1396, 0.7741)>
#
# output: rotation:  <Quaternion (w=0.4971, x=-0.0111, y=-0.0051, z=-0.8676)>
#
# 0.0238855626896 0.023517545957
# output: location:  <Vector (0.5583, -0.0442, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.3945, x=-0.0030, y=0.0011, z=-0.9189)>
#
# 0.0319772131831 0.00157203205671
# output: location:  <Vector (0.4683, -0.0287, 0.7738)>
#
# output: rotation:  <Quaternion (w=0.1987, x=-0.0001, y=-0.0093, z=-0.9800)>
#
# 0.0146666172054 0.00137768293829
# X, y_new [[ 0.13929717  0.21585722]] 0.0969966540302
# output: location:  <Vector (0.5620, -0.1411, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5005, x=0.0002, y=0.0002, z=-0.8658)>
#
# 0.0257178907572 0.0221440028512
# output: location:  <Vector (0.5646, -0.0524, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.3548, x=-0.0004, y=-0.0060, z=-0.9349)>
#
# 0.0419621901592 0.00679683443974
# output: location:  <Vector (0.4693, -0.0172, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.1566, x=-0.0031, y=-0.0018, z=-0.9877)>
#
# 0.0131066075035 0.00624989501531
# X, y_new [[ 0.23209036  0.3287673 ]] 0.115977420726
# output: location:  <Vector (0.5529, -0.1350, 0.7767)>
#
# output: rotation:  <Quaternion (w=0.5661, x=-0.0273, y=-0.0181, z=-0.8237)>
#
# 0.0150704513867 0.00603145174281
# output: location:  <Vector (0.5609, -0.0462, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.3800, x=0.0022, y=0.0047, z=-0.9250)>
#
# 0.0352548005662 0.00299166073431
# output: location:  <Vector (0.4687, -0.0086, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4133, x=-0.0021, y=-0.0005, z=-0.9106)>
#
# 0.0186023804995 0.0354998729061
# X, y_new [[ 0.24651095  0.66331083]] 0.113450617836
# output: location:  <Vector (0.5576, -0.1398, 0.7756)>
#
# output: rotation:  <Quaternion (w=0.5193, x=-0.0104, y=-0.0064, z=-0.8545)>
#
# 0.0217619830209 0.0163455087066
# output: location:  <Vector (0.5654, -0.0540, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.3608, x=0.0032, y=0.0093, z=-0.9326)>
#
# 0.0436014692752 0.00570601595982
# output: location:  <Vector (0.4756, -0.0011, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.3812, x=-0.0038, y=0.0034, z=-0.9245)>
#
# 0.0218563963235 0.0236494308609
# X, y_new [[ 0.46956585  0.65971045]] 0.132920804147
# output: location:  <Vector (0.5510, -0.1354, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.5081, x=-0.0011, y=0.0019, z=-0.8613)>
#
# 0.0143130257109 0.0196998445907
# output: location:  <Vector (0.5610, -0.0544, 0.7739)>
#
# output: rotation:  <Quaternion (w=0.2968, x=-0.0027, y=-0.0116, z=-0.9549)>
#
# 0.0406275941075 0.0203930785922
# output: location:  <Vector (0.4599, -0.0135, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.2911, x=0.0009, y=-0.0001, z=-0.9567)>
#
# 0.0232080688609 0.00350054306393
# X, y_new [[ 0.24454397  0.44762342]] 0.121742154926
# output: location:  <Vector (0.5584, -0.1391, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.5005, x=-0.0028, y=-0.0058, z=-0.8657)>
#
# 0.0217691778669 0.0222314270835
# output: location:  <Vector (0.5513, -0.0328, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.3864, x=0.0057, y=0.0069, z=-0.9223)>
#
# 0.0203894110499 0.00228379315513
# output: location:  <Vector (0.4724, -0.0296, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.1370, x=0.0083, y=0.0022, z=-0.9905)>
#
# 0.0116973313303 0.00994998334899
# X, y_new [[ 0.47994386  0.19125486]] 0.0883211238346
# output: location:  <Vector (0.5609, -0.1376, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.5342, x=0.0072, y=-0.0023, z=-0.8453)>
#
# 0.0225567751463 0.0122094510364
# output: location:  <Vector (0.5550, -0.0395, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.3554, x=-0.0001, y=0.0021, z=-0.9347)>
#
# 0.0266441573888 0.00670323524896
# output: location:  <Vector (0.4757, -0.0366, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.0690, x=0.0156, y=-0.0015, z=-0.9975)>
#
# 0.0155311480661 0.0280277375384
# X, y_new [[ 0.47590298  0.20120453]] 0.111672504425
# output: location:  <Vector (0.5573, -0.1379, 0.7742)>
#
# output: rotation:  <Quaternion (w=0.4882, x=-0.0116, y=-0.0062, z=-0.8726)>
#
# 0.0201413531075 0.0267531504733
# output: location:  <Vector (0.5525, -0.0386, 0.7739)>
#
# output: rotation:  <Quaternion (w=0.3119, x=0.0066, y=-0.0079, z=-0.9501)>
#
# 0.0240428917346 0.016111033731
# output: location:  <Vector (0.4759, -0.0504, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.0767, x=-0.0033, y=-0.0004, z=-0.9970)>
#
# 0.0287719370264 0.0255003621698
# X, y_new [[ 0.48785981  0.17175221]] 0.141320728243
# output: location:  <Vector (0.5621, -0.1399, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.5143, x=0.0046, y=0.0042, z=-0.8576)>
#
# 0.024970392568 0.0177428599604
# output: location:  <Vector (0.5598, -0.0473, 0.7730)>
#
# output: rotation:  <Quaternion (w=0.3403, x=0.0059, y=0.0145, z=-0.9402)>
#
# 0.0350282240909 0.00950033538896
# output: location:  <Vector (0.4738, -0.0281, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.1493, x=0.0051, y=-0.0012, z=-0.9888)>
#
# 0.00966680196601 0.00753035298022
# X, y_new [[ 0.44256495  0.28306637]] 0.104438966954
# output: location:  <Vector (0.5576, -0.1408, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4929, x=0.0002, y=0.0002, z=-0.8701)>
#
# 0.0225353035258 0.0248737131426
# output: location:  <Vector (0.5597, -0.0509, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3266, x=-0.0016, y=-0.0025, z=-0.9452)>
#
# 0.037273033187 0.0124764904451
# output: location:  <Vector (0.4742, -0.0004, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3893, x=0.0010, y=0.0006, z=-0.9211)>
#
# 0.0229339564892 0.0264856776783
# X, y_new [[ 0.2820963   0.58432899]] 0.146578174468
# output: location:  <Vector (0.5581, -0.1363, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.4873, x=-0.0037, y=-0.0064, z=-0.8732)>
#
# 0.0195889485425 0.0269153931891
# output: location:  <Vector (0.5580, -0.0416, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3563, x=-0.0027, y=-0.0038, z=-0.9343)>
#
# 0.0302981722709 0.00659377109198
# output: location:  <Vector (0.4646, -0.0270, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.1423, x=0.0003, y=-0.0012, z=-0.9898)>
#
# 0.0175108811957 0.0088853596948
# X, y_new [[ 0.13866305  0.2144057 ]] 0.109792525985
# output: location:  <Vector (0.5568, -0.1375, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4851, x=-0.0015, y=-0.0008, z=-0.8744)>
#
# 0.0195080164292 0.027840819102
# output: location:  <Vector (0.5592, -0.0427, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3694, x=-0.0006, y=-0.0001, z=-0.9293)>
#
# 0.0318973504066 0.00443496442645
# output: location:  <Vector (0.4740, -0.0348, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.0803, x=-0.0008, y=0.0024, z=-0.9968)>
#
# 0.0146581294936 0.0241959319764
# X, y_new [[ 0.47857913  0.19465061]] 0.122535211834
# optima!!!!!!!!!!!!!!!!:  [ 0.47994386  0.19125486] [ 0.08832112] 329.550250053
# output: location:  <Vector (0.5552, -0.1369, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5006, x=-0.0014, y=-0.0004, z=-0.8657)>
#
# 0.0179978972383 0.0221752839891
# output: location:  <Vector (0.5580, -0.0476, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3155, x=0.0010, y=0.0003, z=-0.9489)>
#
# 0.0338183743394 0.0153676778025
# output: location:  <Vector (0.4621, -0.0127, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.2616, x=0.0049, y=0.0095, z=-0.9651)>
#
# 0.0215226778132 0.000827652101095
# X, y_new [[ 0.03605421  0.36431636]] 0.111709563284
# output: location:  <Vector (0.5513, -0.1356, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.5042, x=0.0065, y=0.0060, z=-0.8636)>
#
# 0.0146406046665 0.0209171302136
# output: location:  <Vector (0.5521, -0.0350, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4050, x=-0.0036, y=0.0007, z=-0.9143)>
#
# 0.0219700050742 0.000840401389143
# output: location:  <Vector (0.4720, -0.0443, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.0248, x=-0.0046, y=-0.0001, z=-0.9997)>
#
# 0.0240604501257 0.0442490014273
# X, y_new [[ 0.14196427  0.13790421]] 0.126677592896
# output: location:  <Vector (0.5563, -0.1400, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4899, x=0.0023, y=-0.0002, z=-0.8718)>
#
# 0.0211060111106 0.025950874677
# output: location:  <Vector (0.5620, -0.0540, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3158, x=0.0002, y=0.0001, z=-0.9488)>
#
# 0.0410678526704 0.0153034997202
# output: location:  <Vector (0.4840, -0.0322, 0.7739)>
#
# output: rotation:  <Quaternion (w=0.0600, x=-0.0021, y=-0.0091, z=-0.9982)>
#
# 0.0103593513431 0.0307813263001
# X, y_new [[ 0.31357864  0.49325142]] 0.144568915821
# output: location:  <Vector (0.5624, -0.1444, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4749, x=0.0023, y=-0.0003, z=-0.8801)>
#
# 0.0283819644317 0.0316103886228
# output: location:  <Vector (0.5660, -0.0580, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3405, x=0.0007, y=0.0011, z=-0.9403)>
#
# 0.0467227281198 0.00941078870825
# output: location:  <Vector (0.4738, -0.0014, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.3728, x=0.0109, y=0.0078, z=-0.9278)>
#
# 0.0221219655603 0.0210939879366
# X, y_new [[ 0.28753067  0.39004171]] 0.159341823379
# output: location:  <Vector (0.5609, -0.1415, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4909, x=0.0018, y=0.0001, z=-0.8712)>
#
# 0.0252300714426 0.0256450687409
# output: location:  <Vector (0.5587, -0.0507, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3000, x=-0.0018, y=-0.0010, z=-0.9540)>
#
# 0.03640304332 0.0194416446268
# output: location:  <Vector (0.4732, -0.0286, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.1654, x=0.0032, y=0.0044, z=-0.9862)>
#
# 0.0104474188319 0.00499941009423
# X, y_new [[ 0.14614698  0.33104606]] 0.122166657056
# output: location:  <Vector (0.5656, -0.1482, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4642, x=0.0044, y=0.0038, z=-0.8857)>
#
# 0.0333484378195 0.0360898861663
# output: location:  <Vector (0.5610, -0.0470, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.3585, x=0.0034, y=0.0011, z=-0.9335)>
#
# 0.0358043869234 0.00617743665789
# output: location:  <Vector (0.4627, -0.0184, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.1754, x=0.0030, y=-0.0051, z=-0.9845)>
#
# 0.0191045638592 0.00360789185937
# X, y_new [[ 0.10697655  0.29660007]] 0.134132603286
# output: location:  <Vector (0.5615, -0.1394, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5093, x=-0.0002, y=-0.0005, z=-0.8606)>
#
# 0.0241899918355 0.0193167749652
# output: location:  <Vector (0.5589, -0.0455, 0.7741)>
#
# output: rotation:  <Quaternion (w=0.3333, x=0.0008, y=-0.0073, z=-0.9428)>
#
# 0.0332239510438 0.0109920148441
# output: location:  <Vector (0.4654, -0.0155, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.1935, x=0.0065, y=0.0015, z=-0.9811)>
#
# 0.0173601975867 0.00177777737379
# X, y_new [[ 0.03468427  0.30541779]] 0.106860707649
# output: location:  <Vector (0.5514, -0.1364, 0.7769)>
#
# output: rotation:  <Quaternion (w=0.5359, x=-0.0336, y=-0.0193, z=-0.8434)>
#
# 0.0153762773453 0.0128899179063
# output: location:  <Vector (0.5551, -0.0468, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.2999, x=-0.0007, y=0.0001, z=-0.9540)>
#
# 0.0311115104577 0.0195535933469
# output: location:  <Vector (0.4600, -0.0250, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.2577, x=0.0102, y=0.0062, z=-0.9662)>
#
# 0.0216167749734 0.000548233359442
# X, y_new [[ 0.22302864  0.53098063]] 0.101096307389
# output: location:  <Vector (0.5628, -0.1393, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.4907, x=-0.0011, y=-0.0081, z=-0.8713)>
#
# 0.0251048103956 0.0256314014875
# output: location:  <Vector (0.5590, -0.0415, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3811, x=-0.0003, y=-0.0000, z=-0.9245)>
#
# 0.0311050080045 0.00304080190167
# output: location:  <Vector (0.4738, -0.0296, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.1322, x=-0.0010, y=-0.0006, z=-0.9912)>
#
# 0.0106538049658 0.0108959726998
# X, y_new [[ 0.39846739  0.18758119]] 0.106431799455
# output: location:  <Vector (0.5628, -0.1411, 0.7741)>
#
# output: rotation:  <Quaternion (w=0.5056, x=0.0056, y=-0.0048, z=-0.8627)>
#
# 0.026297382094 0.0205940739231
# output: location:  <Vector (0.5604, -0.0453, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3925, x=0.0010, y=0.0009, z=-0.9198)>
#
# 0.0343289743942 0.00169599496583
# output: location:  <Vector (0.4608, -0.0195, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.2293, x=0.0054, y=0.0012, z=-0.9733)>
#
# 0.0208013571733 0.000167424023712
# X, y_new [[ 0.37834505  0.29831261]] 0.103885206574
# output: location:  <Vector (0.5531, -0.1384, 0.7752)>
#
# output: rotation:  <Quaternion (w=0.5022, x=-0.0080, y=-0.0077, z=-0.8647)>
#
# 0.0179689873115 0.0216663438276
# output: location:  <Vector (0.5588, -0.0502, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3150, x=-0.0020, y=-0.0028, z=-0.9491)>
#
# 0.0361364409282 0.0153873221375
# output: location:  <Vector (0.4705, -0.0056, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3778, x=-0.0003, y=-0.0001, z=-0.9259)>
#
# 0.019845592968 0.0226059523138
# X, y_new [[ 0.22030323  0.53258652]] 0.133610639487
# output: location:  <Vector (0.5558, -0.1384, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5069, x=0.0006, y=0.0005, z=-0.8620)>
#
# 0.01953676291 0.0201162125033
# output: location:  <Vector (0.5564, -0.0494, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.2858, x=-0.0003, y=-0.0000, z=-0.9583)>
#
# 0.0338420301247 0.0238820765465
# output: location:  <Vector (0.4751, -0.0363, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.1680, x=0.0093, y=-0.0011, z=-0.9857)>
#
# 0.0154881006018 0.00477962434018
# X, y_new [[ 0.22694983  0.5206156 ]] 0.117644807026
# output: location:  <Vector (0.5529, -0.1374, 0.7768)>
#
# output: rotation:  <Quaternion (w=0.5325, x=-0.0320, y=-0.0194, z=-0.8456)>
#
# 0.0170191922546 0.013683530577
# output: location:  <Vector (0.5658, -0.0565, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3391, x=0.0020, y=0.0005, z=-0.9407)>
#
# 0.0455536905526 0.00988366047536
# output: location:  <Vector (0.4619, -0.0268, 0.7745)>
#
# output: rotation:  <Quaternion (w=0.2453, x=0.0055, y=0.0077, z=-0.9694)>
#
# 0.0200725872834 0.000138010485948
# X, y_new [[ 0.2355437   0.53040716]] 0.106350671629
# output: location:  <Vector (0.5606, -0.1414, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.4893, x=0.0018, y=-0.0017, z=-0.8721)>
#
# 0.0249517034489 0.0262063272947
# output: location:  <Vector (0.5615, -0.0473, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.3636, x=0.0020, y=-0.0023, z=-0.9315)>
#
# 0.0363849733126 0.00540167877049
# output: location:  <Vector (0.4632, -0.0135, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.2234, x=-0.0055, y=0.0035, z=-0.9747)>
#
# 0.0201843122313 0.000172881847321
# X, y_new [[ 0.38427855  0.2821605 ]] 0.113301876905
# output: location:  <Vector (0.5626, -0.1438, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.4824, x=-0.0044, y=-0.0013, z=-0.8759)>
#
# 0.0280713003796 0.0288508080166
# output: location:  <Vector (0.5531, -0.0419, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3144, x=0.0034, y=0.0006, z=-0.9493)>
#
# 0.0264246817003 0.0155562209043
# output: location:  <Vector (0.4708, -0.0227, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.1618, x=-0.0019, y=-0.0061, z=-0.9868)>
#
# 0.0106434797059 0.00549714340549
# X, y_new [[ 0.37659192  0.31088485]] 0.115043634112
# output: location:  <Vector (0.5600, -0.1409, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4991, x=0.0031, y=0.0030, z=-0.8665)>
#
# 0.0241769043717 0.0227595173381
# output: location:  <Vector (0.5589, -0.0485, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.3226, x=0.0018, y=-0.0023, z=-0.9465)>
#
# 0.0350867855889 0.0135647692377
# output: location:  <Vector (0.4641, -0.0131, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.2277, x=0.0006, y=0.0004, z=-0.9737)>
#
# 0.0195574553623 0.000176004726902
# X, y_new [[ 0.36820678  0.2929585 ]] 0.115321436626
# output: location:  <Vector (0.5645, -0.1427, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.5085, x=0.0003, y=0.0004, z=-0.8611)>
#
# 0.0286318791734 0.0195329335707
# output: location:  <Vector (0.5574, -0.0432, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3482, x=0.0007, y=0.0018, z=-0.9374)>
#
# 0.0306670892482 0.00801635875024
# output: location:  <Vector (0.4746, -0.0314, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.1568, x=-0.0010, y=-0.0049, z=-0.9876)>
#
# 0.0114866600999 0.0063081922514
# X, y_new [[ 0.38734474  0.29845919]] 0.104643113094
# optima!!!!!!!!!!!!!!!!:  [ 0.22302864  0.53098063] [ 0.10109631] 321.488965034
# output: location:  <Vector (0.5538, -0.1345, 0.7763)>
#
# output: rotation:  <Quaternion (w=0.5755, x=-0.0212, y=-0.0144, z=-0.8174)>
#
# 0.0152696006824 0.00418853429963
# output: location:  <Vector (0.5623, -0.0474, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3921, x=0.0012, y=0.0008, z=-0.9199)>
#
# 0.0370914168368 0.00185848830198
# output: location:  <Vector (0.4681, -0.0063, 0.7745)>
#
# output: rotation:  <Quaternion (w=0.3827, x=0.0104, y=0.0028, z=-0.9238)>
#
# 0.0207212755459 0.0242783472039
# X, y_new [[ 0.17753294  0.6839835 ]] 0.103407662871
# output: location:  <Vector (0.5595, -0.1421, 0.7739)>
#
# output: rotation:  <Quaternion (w=0.4820, x=-0.0097, y=0.0066, z=-0.8761)>
#
# 0.0247451188116 0.0289777146247
# output: location:  <Vector (0.5619, -0.0513, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.3211, x=0.0036, y=0.0012, z=-0.9471)>
#
# 0.0391863838975 0.0137646811155
# output: location:  <Vector (0.4609, -0.0199, 0.7741)>
#
# output: rotation:  <Quaternion (w=0.2683, x=-0.0183, y=-0.0034, z=-0.9631)>
#
# 0.0206545118618 0.00161333296775
# X, y_new [[ 0.0859969   0.34129379]] 0.128941743279
# output: location:  <Vector (0.5553, -0.1268, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.5175, x=-0.0014, y=-0.0005, z=-0.8557)>
#
# 0.0122868427596 0.0167695610218
# output: location:  <Vector (0.5397, 0.0097, 0.7735)>
#
# output: rotation:  <Quaternion (w=0.2430, x=0.0063, y=0.0051, z=-0.9700)>
#
# 0.0362849374115 0.03919060135
# output: location:  <Vector (0.4520, -0.0534, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.0689, x=-0.0030, y=-0.0025, z=0.9976)>
#
# 0.0429159802434 0.0906910155143
# X, y_new [[ 0.07666039  0.08619868]] 0.238138938301
# output: location:  <Vector (0.5519, -0.1178, 0.7729)>
#
# output: rotation:  <Quaternion (w=0.4388, x=0.0039, y=0.0144, z=-0.8985)>
#
# 0.00991954157207 0.0473929933618
# output: location:  <Vector (0.5537, 0.0081, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.1970, x=0.0017, y=-0.0001, z=-0.9804)>
#
# 0.040160928811 0.0596043018939
# output: location:  <Vector (0.4403, -0.0343, 0.7737)>
#
# output: rotation:  <Quaternion (w=0.0177, x=0.0130, y=0.0044, z=0.9997)>
#
# 0.0428829483624 0.063784669624
# X, y_new [[ 0.08528862  0.09375415]] 0.263745383625
# output: location:  <Vector (0.5540, -0.1365, 0.7762)>
#
# output: rotation:  <Quaternion (w=0.5379, x=-0.0202, y=-0.0134, z=-0.8427)>
#
# 0.0169295098866 0.0115438028493
# output: location:  <Vector (0.5618, -0.0527, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3222, x=0.0011, y=0.0009, z=-0.9467)>
#
# 0.0400376992716 0.0135772058266
# output: location:  <Vector (0.4674, -0.0222, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.1690, x=0.0061, y=0.0038, z=-0.9856)>
#
# 0.0140300449126 0.00447560371304
# X, y_new [[ 0.07756351  0.49519859]] 0.10059386646
# output: location:  <Vector (0.5562, -0.1392, 0.7755)>
#
# output: rotation:  <Quaternion (w=0.5178, x=-0.0103, y=-0.0073, z=-0.8554)>
#
# 0.0204117883832 0.016794643227
# output: location:  <Vector (0.5653, -0.0562, 0.7735)>
#
# output: rotation:  <Quaternion (w=0.3436, x=0.0077, y=-0.0013, z=-0.9391)>
#
# 0.0449822916597 0.00882211171231
# output: location:  <Vector (0.4678, -0.0278, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.1896, x=0.0003, y=0.0002, z=-0.9819)>
#
# 0.0147490935399 0.00210179009349
# X, y_new [[ 0.42557104  0.59214473]] 0.107861718616
# output: location:  <Vector (0.5549, -0.1338, 0.7757)>
#
# output: rotation:  <Quaternion (w=0.5868, x=-0.0145, y=-0.0079, z=-0.8096)>
#
# 0.0155411487671 0.00235311477762
# output: location:  <Vector (0.5623, -0.0511, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3583, x=-0.0017, y=-0.0026, z=-0.9336)>
#
# 0.0393619974463 0.00616810192454
# output: location:  <Vector (0.4751, 0.0007, 0.7743)>
#
# output: rotation:  <Quaternion (w=0.3768, x=-0.0019, y=0.0047, z=-0.9263)>
#
# 0.0237245497376 0.0222168206554
# X, y_new [[ 0.07483098  0.67373045]] 0.109365733308
# output: location:  <Vector (0.5579, -0.1376, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.5326, x=-0.0007, y=-0.0002, z=-0.8464)>
#
# 0.0203414381252 0.0124976241495
# output: location:  <Vector (0.5661, -0.0421, 0.7745)>
#
# output: rotation:  <Quaternion (w=0.4234, x=0.0016, y=0.0059, z=-0.9059)>
#
# 0.0376612432477 0.000120780312809
# output: location:  <Vector (0.4707, -0.0418, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.0309, x=-0.0001, y=0.0025, z=-0.9995)>
#
# 0.0223760085862 0.041812728508
# X, y_new [[ 0.07205878  0.17450931]] 0.134809822929
# output: location:  <Vector (0.5647, -0.1449, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.4770, x=-0.0043, y=-0.0020, z=-0.8789)>
#
# 0.0303144075482 0.030859783214
# output: location:  <Vector (0.5587, -0.0464, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3626, x=-0.0021, y=-0.0026, z=-0.9319)>
#
# 0.0336074039902 0.00553398489247
# output: location:  <Vector (0.4667, -0.0219, 0.7741)>
#
# output: rotation:  <Quaternion (w=0.1990, x=0.0042, y=-0.0041, z=-0.9800)>
#
# 0.0147323745625 0.0013050683171
# X, y_new [[ 0.00637708  0.35187094]] 0.116353022524
# output: location:  <Vector (0.5622, -0.1439, 0.7745)>
#
# output: rotation:  <Quaternion (w=0.4826, x=-0.0013, y=0.0026, z=-0.8758)>
#
# 0.0278758372968 0.0287349984612
# output: location:  <Vector (0.5572, -0.0473, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3159, x=0.0008, y=-0.0002, z=-0.9488)>
#
# 0.0330147252444 0.0152092170487
# output: location:  <Vector (0.4705, -0.0311, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.1907, x=-0.0028, y=-0.0006, z=-0.9816)>
#
# 0.0141176506633 0.00215072981708
# X, y_new [[ 0.42802368  0.25166676]] 0.121103158531
# output: location:  <Vector (0.5576, -0.1389, 0.7764)>
#
# output: rotation:  <Quaternion (w=0.5403, x=-0.0240, y=-0.0153, z=-0.8410)>
#
# 0.0210823031237 0.0111918507727
# output: location:  <Vector (0.5658, -0.0571, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3395, x=0.0014, y=0.0006, z=-0.9406)>
#
# 0.0459602985517 0.00972678848043
# output: location:  <Vector (0.4822, -0.0341, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.0995, x=-0.0033, y=0.0004, z=-0.9950)>
#
# 0.0119603118793 0.0187739379284
# X, y_new [[ 0.07643206  0.49213559]] 0.118695490736
# output: location:  <Vector (0.5522, -0.1372, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.4864, x=-0.0002, y=-0.0001, z=-0.8738)>
#
# 0.0164747414244 0.0271721249633
# output: location:  <Vector (0.5608, -0.0521, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3209, x=-0.0001, y=0.0004, z=-0.9471)>
#
# 0.0388946402858 0.013990671371
# output: location:  <Vector (0.4776, -0.0285, 0.7746)>
#
# output: rotation:  <Quaternion (w=0.1321, x=0.0023, y=0.0017, z=-0.9912)>
#
# 0.00740320607913 0.0109181451356
# X, y_new [[ 0.07787193  0.49603359]] 0.114853529259
# output: location:  <Vector (0.5579, -0.1372, 0.7766)>
#
# output: rotation:  <Quaternion (w=0.5613, x=-0.0260, y=-0.0178, z=-0.8270)>
#
# 0.0200597035123 0.0068612945608
# output: location:  <Vector (0.5666, -0.0502, 0.7745)>
#
# output: rotation:  <Quaternion (w=0.3979, x=-0.0066, y=0.0028, z=-0.9174)>
#
# 0.0422181899536 0.00128460062112
# output: location:  <Vector (0.4767, -0.0265, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.1097, x=0.0046, y=-0.0014, z=-0.9939)>
#
# 0.00641634321479 0.0161304017168
# X, y_new [[ 0.16778949  0.68344279]] 0.0929705335794
# output: location:  <Vector (0.5616, -0.1374, 0.7764)>
#
# output: rotation:  <Quaternion (w=0.5753, x=-0.0236, y=-0.0163, z=-0.8175)>
#
# 0.0229748015225 0.00426208661676
# output: location:  <Vector (0.5665, -0.0509, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3912, x=0.0027, y=-0.0005, z=-0.9203)>
#
# 0.042545954014 0.0018964607036
# output: location:  <Vector (0.4838, 0.0072, 0.7749)>
#
# output: rotation:  <Quaternion (w=0.3251, x=0.0014, y=0.0013, z=-0.9457)>
#
# 0.0294599857476 0.00890520682855
# X, y_new [[ 0.16515053  0.68329727]] 0.110044495433
# output: location:  <Vector (0.5565, -0.1376, 0.7763)>
#
# output: rotation:  <Quaternion (w=0.5486, x=-0.0265, y=-0.0124, z=-0.8356)>
#
# 0.0193800130289 0.00932890281848
# output: location:  <Vector (0.5646, -0.0525, 0.7747)>
#
# output: rotation:  <Quaternion (w=0.3630, x=0.0017, y=0.0028, z=-0.9318)>
#
# 0.0420256721893 0.00537280793124
# output: location:  <Vector (0.4631, -0.0086, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.3041, x=-0.0033, y=0.0039, z=-0.9526)>
#
# 0.0228031699606 0.00529714704098
# X, y_new [[ 0.40076612  0.59592684]] 0.104207712969
# output: location:  <Vector (0.5562, -0.1380, 0.7769)>
#
# output: rotation:  <Quaternion (w=0.5448, x=-0.0305, y=-0.0198, z=-0.8378)>
#
# 0.0194836830451 0.0105374817031
# output: location:  <Vector (0.5604, -0.0519, 0.7748)>
#
# output: rotation:  <Quaternion (w=0.3309, x=-0.0019, y=-0.0020, z=-0.9437)>
#
# 0.0384649451184 0.0114940128758
# output: location:  <Vector (0.4669, -0.0071, 0.7742)>
#
# output: rotation:  <Quaternion (w=0.3495, x=0.0120, y=0.0044, z=-0.9369)>
#
# 0.0209298843821 0.0144387199603
# X, y_new [[ 0.41144141  0.61409809]] 0.115348727085
# output: location:  <Vector (0.5544, -0.1377, 0.7771)>
#
# output: rotation:  <Quaternion (w=0.5367, x=-0.0347, y=-0.0220, z=-0.8428)>
#
# 0.018125857359 0.0127969930269
# output: location:  <Vector (0.5614, -0.0532, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.2934, x=-0.0032, y=-0.0071, z=-0.9560)>
#
# 0.0400826441613 0.0213825142309
# output: location:  <Vector (0.4755, -0.0217, 0.7744)>
#
# output: rotation:  <Quaternion (w=0.1247, x=0.0113, y=-0.0037, z=-0.9921)>
#
# 0.00594816444376 0.0125524569084
# X, y_new [[ 0.40520534  0.57482505]] 0.11088863013
# optima!!!!!!!!!!!!!!!!:  [ 0.16778949  0.68344279] [ 0.09297053] 320.646390915

# %%
myBopt.Y_best
# Out:
# array([ 0.10854235,  0.10854235,  0.10854235,  0.10854235,  0.10854235,
#         0.10854235,  0.10854235,  0.10854235,  0.10854235,  0.10854235,
#         0.10854235,  0.10085571,  0.10085571,  0.10085571,  0.10085571,
#         0.10085571,  0.10085571,  0.10085571,  0.10085571,  0.09533078,
#         0.09533078])

# %%
BO_result[3].Y_best
# Out:
# array([ 0.08526639])

# %%
data = np.empty([5,20])
for i in xrange(0,2):  
    print len(BO_result[i].Y_best)
    for j in xrange(0,len(BO_result[i].Y_best)):
        
        data[i][j] = BO_result[i].Y_best[j]
# Out:
# 13
# 13

# %%
data
# Out:
# array([[  1.16305315e-001,   4.94065646e-324],
#        [  1.10680606e-001,   9.88131292e-324]])

# %%
dm = np.mean(data, axis=0)

# %%
dm
# Out:
# array([  0.1596841 ,   0.11176451,   0.10853314,   0.10503767,
#          0.10503767,   0.10503767,   0.10140117,   0.10140117,
#          0.09941571,   0.09941571,   0.09297646,   0.09297646,
#          0.09297646,  11.82095694,  11.82095663,  15.29793707,
#         12.19609045,  12.19608744,  12.19608737,  12.19608737])

# %%
ds = np.std(data, axis=0)

# %%
ds
# Out:
# array([  4.85526708e-02,   6.33075577e-04,   3.86444428e-03,
#          7.35990764e-03,   7.35990764e-03,   7.35990764e-03,
#          3.72340555e-03,   3.72340555e-03,   1.73794746e-03,
#          1.73794746e-03,   4.70131000e-03,   4.70131000e-03,
#          4.70131000e-03,   4.31913406e-01,   4.31913709e-01,
#          3.10030162e+00,   1.55118508e-03,   1.54817566e-03,
#          1.54810115e-03,   1.54810238e-03])
