# %%
#!/usr/bin/env python
# a bar plot with errorbars
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
# %matplotlib inline
 
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

N = 5
menMeans = (20, 35, 30, 35, 27)
menStd = (2, 3, 4, 1, 2)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, menMeans, width, color='r', yerr=menStd)

womenMeans = (25, 32, 34, 20, 25)
womenStd = (3, 5, 2, 3, 3)
rects2 = ax.bar(ind + width, womenMeans, width, color='y', yerr=womenStd)

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))

ax.legend((rects1[0], rects2[0]), ('Men', 'Women'))


def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %%
# %matplotlib inline

#!/usr/bin/env python
# a bar plot with errorbars
import numpy as np
import matplotlib.pyplot as plt

N = 3
ensemble = (0.0264741971872, 0.0177323758419, 0.065513007945)
# menStd = (2, 3, 4, 1, 2)

ind = np.arange(N)  # the x locations for the groups
width = 0.45       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, ensemble, width, color='r', alpha=0.5)

exp3 = (0.0305290028777, 0.0179359792875, 0.0732959822228)
# womenStd = (3, 5, 2, 3, 3)
rects2 = ax.bar(ind + width, exp3, width, color='y',  alpha=0.5)

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
# ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width)
ax.set_xticklabels(('exp4', 'exp6', 'exp8',))

# ax.legend((rects1[0], rects2[0]), ('ensemble', 'exp3'))


def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
                '%f' % float(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %%
ensemble = (0.0333412160444,0.0286136924044,0.105444821755)
fig, ax = plt.subplots()
rects1 = ax.bar(ind, ensemble, width, color='r', alpha=0.5)

exp3 = (0.0557400196798,0.0360265488141,0.202558578716)
rects2 = ax.bar(ind + width, exp3, width, color='y',  alpha=0.5)
# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
# ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width)
ax.set_xticklabels(('exp4', 'exp6', 'exp8',))


autolabel(rects1)
autolabel(rects2)

plt.show()

# %%
fig, ax = plt.subplots()
GS = (0.0285145519465+0.0477484785119,0.0205988968879 +0.0196046033652,0.0712715806616+0.200364586767)
rects2 = ax.bar(ind, GS, width, color='y',  alpha=0.5)
ensemble3 = (0.0264741971872+0.0333412160444,0.0177323758419+0.0186136924044,0.065513007945+0.105444821755)
rects1 = ax.bar(ind + width, ensemble3, width, color='r', alpha=0.5)


# add some text for labels, title and axes ticks
ax.set_ylabel('Error')
# ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width)
ax.set_xticklabels(('test1', 'test2', 'test3',))


ax.legend((rects2[1], rects1[1]), ('Random Search','Bayesian Optimization'),bbox_to_anchor=(0.6, 1),)


# autolabel(rects1)
# autolabel(rects2)
ax.set_title('Perfomance Comparison')
# plt.show()
savefig('GS_BO.pdf')

# %%
savefig('test.png')

# %%
N = 3
ind = 3*np.arange(N)  # the x locations for the groups
width = 0.9       # the width of the bars


fig, ax = plt.subplots()
single = (0.0356176461422+0.04556437340,0.0170199986193+0.035238740083,0.0697547461468+0.151452776579)
rects1 = ax.bar(ind-width, single, width, color='y',  alpha=0.5)
ensemble3 = (0.0264741971872+0.0333412160444,0.0177323758419+0.0186136924044,0.065513007945+0.105444821755)
rects2 = ax.bar(ind, ensemble3, width, color='r', alpha=0.5)
ensemble6 = ( 0.0251184218594+0.0392184156787,0.018773496025+0.0215886534714,0.0512897983034+0.0166862503877)
rects3 = ax.bar(ind + width, ensemble6, width, color='b', alpha=0.5)


# add some text for labels, title and axes ticks
ax.set_ylabel('Error')
# ax.set_title('Scores by group and gender')
ax.set_xticks(ind+width/2)
ax.set_xticklabels(('test1', 'test2', 'test3',))


ax.legend((rects1[1], rects2[1],rects3[1]), ('1 sample','3 samples','6 samples'),bbox_to_anchor=(0.4, 1),)


# autolabel(rects1)
# autolabel(rects2)
# autolabel(rects3)
ax.set_title('Perfomance Comparison')


plt.show()

# %%
N = 1
ind = np.arange(N)  # the x locations for the groups
width = 0.5       # the width of the bars


fig, ax = plt.subplots()
single = (0.0356176461422+0.04556437340)
rects1 = ax.bar(ind-width, single, width, color='y',  alpha=0.5)
ensemble3 = (0.0264741971872+0.0333412160444)
rects2 = ax.bar(ind, ensemble3, width, color='r', alpha=0.5)
ensemble6 = ( 0.0251184218594+0.0392184156787)
rects3 = ax.bar(ind + width, ensemble6, width, color='b', alpha=0.5)


# add some text for labels, title and axes ticks
ax.set_ylabel('Error')
# ax.set_title('Scores by group and gender')
ind3 = 0.5*np.arange(3)  # the x locations for the groups

ax.set_xticks(ind3-width/2)
# ax.set_xlabel(('test1',   'test2',    'test3'))

ax.set_xticklabels(('1 sample',   '3 samples',    '6 samples',))
# ax.set_xticks(ind)
# ax.set_xticklabels(( 'test2', 'test3',))




# ax.legend((rects1[0], rects2[0],rects3[0]), ('1 sample','3 samples','6 samples'),bbox_to_anchor=(0.4, 1),)


# autolabel(rects1)
# autolabel(rects2)
# autolabel(rects3)
ax.set_title('Test action 1')

# plt.show()
savefig('test1.pdf')

# %%
N = 1
ind = np.arange(N)  # the x locations for the groups
width = 0.5       # the width of the bars

fig, ax = plt.subplots()
single = (0.0170199986193+0.035238740083)
rects1 = ax.bar(ind-width, single, width, color='y',  alpha=0.5)
ensemble3 = (0.0177323758419+0.0186136924044)
rects2 = ax.bar(ind, ensemble3, width, color='r', alpha=0.5)
ensemble6 = ( 0.018773496025+0.0215886534714)
rects3 = ax.bar(ind + width, ensemble6, width, color='b', alpha=0.5)

ax.set_ylabel('Error')
ind3 = 0.5*np.arange(3)  # the x locations for the groups

ax.set_xticks(ind3-width/2)

ax.set_xticklabels(('1 sample',   '3 samples',    '6 samples',))

ax.set_title('Test action 2')

# plt.show()
savefig('test2.pdf')

# %%
N = 1
ind = np.arange(N)  # the x locations for the groups
width = 0.5       # the width of the bars

fig, ax = plt.subplots()
single = (0.0697547461468+0.151452776579)
rects1 = ax.bar(ind-width, single, width, color='y',  alpha=0.5)
ensemble3 = (0.065513007945+0.105444821755)
rects2 = ax.bar(ind, ensemble3, width, color='r', alpha=0.5)
ensemble6 = ( 0.0512897983034+0.0166862503877)
rects3 = ax.bar(ind + width, ensemble6, width, color='b', alpha=0.5)

ax.set_ylabel('Error')
ind3 = 0.5*np.arange(3)  # the x locations for the groups

ax.set_xticks(ind3-width/2)

ax.set_xticklabels(('1 sample',   '3 samples',    '6 samples',))

ax.set_title('Test action 3')

# plt.show()
savefig('sample.pdf')

# %%
N = 1 ind = 3*np.arange(N) # the x locations for the groups width = 0.9 # the width of the bars
fig, ax = plt.subplots() single = (0.0356176461422+0.04556437340) rects1 = ax.bar(ind-width, single, width, color='y', alpha=0.5) ensemble3 = (0.0264741971872+0.0333412160444) rects2 = ax.bar(ind, ensemble3, width, color='r', alpha=0.5) ensemble6 = ( 0.0251184218594+0.0392184156787) rects3 = ax.bar(ind + width, ensemble6, width, color='b', alpha=0.5)
add some text for labels, title and axes ticks
ax.set_ylabel('Error')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind-width/2) ax.set_xticklabels(('1 sample','3 samples','6 samples'))
ax.legend((rects1[0], rects2[0],rects3[0]), ('1 sample','3 samples','6 samples'),bbox_to_anchor=(0.4, 1),)
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
ax.set_title('Perfomance Comparison')
plt.show()
# Out:
#   File "<ipython-input-176-fa1f920a5d1d>", line 1
#     N = 1 ind = 3*np.arange(N) # the x locations for the groups width = 0.9 # the width of the bars
#             ^
# SyntaxError: invalid syntax

# %%
test1 = [0.0356176461422+0.04556437340,0.0264741971872+0.0333412160444,0.0251184218594+0.0392184156787]
test2 = [0.0170199986193+0.035238740083,0.0177323758419+0.0186136924044,0.018773496025+0.0215886534714]
test3 = [0.0697547461468+0.151452776579,0.065513007945+0.105444821755,0.0512897983034+0.0166862503877]

# %%
fig, ax = plt.subplots()
ax.plot(ind[1:4],test1)
ax.set_ylabel('Error')

N = 5
ind = np.arange(N)
ax.set_xticks(ind[1:4])

ax.set_xticklabels(('1 sample', '1 sample', '6 samples',))

# %%
ind
# Out:
# array([0, 3, 6])

# %%
BO = [0.93477856628, \
      0.299288369997,0.299288369997,0.299288369997,0.299288369997, \
    0.185471108597,0.185471108597,0.185471108597,0.185471108597,0.185471108597,0.185471108597, \
    0.13374981,0.13374981,0.13374981, \
    0.102312412,0.102312412,0.102312412,0.102312412,0.102312412,0.102312412,0.102312412,0.102312412,0.102312412,0.102312412,0.102312412,\
      0.08030476,0.08030476,0.08030476,0.08030476,0.08030476,0.08030476,0.08030476]
GS =[0.36616351,  0.36616351,  0.36616351,  0.36616351,  0.36616351,
         0.36616351,  0.36616351,  0.36616351,  0.36616351,  0.36616351,
         0.36616351,  0.36616351,  0.36616351,  0.36616351,      
         0.16165194,   0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194,
      0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194, 0.16165194,\
      0.11997654,  0.11968241,   0.11997654,  0.11968241,   0.11997654,  0.11968241,   0.11997654,  0.11968241,  \
     0.11154412,0.11154412,0.11154412,0.11154412,0.11154412,0.11154412,0.11154412,0.11154412,0.11154412,0.11154412,0.11154412,\
     0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,\
          0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,\
     0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,\
     0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692,0.08474692]

pBO = plt.plot(BO,'-o')
pGS = plt.plot(GS,'-o')
plt.ylabel('Error')
plt.title('Convergence Comparison')

# plt.xlabel('Iterations')
plt.legend((pBO[0],pGS[0]),('Bayesian Optimization', 'Grid Search'))

# %%
BO = np.array([0.93477856628,0.2])
bo_std = np.array([0.1,0.1])
GS =[0.36616351,  0.36616351]

pBO = plt.errorbar([1,2],BO,bo_std, linestyle='None', marker='^')
# pGS = plt.plot(GS,'-o')
plt.ylabel('Error')
plt.title('Convergence Comparison')

# plt.xlabel('Iterations')
plt.legend((pBO[0],pGS[0]),('Bayesian Optimization', 'Grid Search'))

# %%
GS[0]
# Out:
# 0.36616351
